# %% [markdown]
# # AISC2009 - Natural Language Processing 01 (M07 Group 1)

# %% [markdown]
# SECTION B QUESTION 2

# %%
#Import required libraries
import pandas as pd
import re
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Taranjot\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Taranjot\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Taranjot\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Load dataset
file_path = "D:\\Downloads\\Data.csv"  # Change the path based on your location
data = pd.read_csv(file_path)

# Clean the 'Data' column
def clean_data(column):
    column = column.str.lower()             # Convert to lowercase
    column = column.str.strip()             # Remove leading/trailing whitespace
    return column

data_cleaned = clean_data(data["Data"])

# %%
# Tokenization
tokens = data_cleaned.apply(word_tokenize)

# Remove stopwords
stop_words = set(stopwords.words('english'))
tokens = tokens.apply(lambda x: [word for word in x if word.isalpha() and word not in stop_words])

# %%
# Count unique words Before lemmatization
words_before_lemmatization = set(tokens.explode())
print("Unique words before lemmatization:", len(words_before_lemmatization))
# Out:
# Unique words before lemmatization: 7056

# %%
# Lemmatization
lemmatizer = WordNetLemmatizer()
tokens_lemmatized = tokens.apply(
    lambda word_list: [lemmatizer.lemmatize(word) for word in word_list]
)

# %%
# Count unique words after lemmatization
unique_after_lemma = set(tokens_lemmatized.explode())
print("Unique words after lemmatization:", len(unique_after_lemma))
# Out:
# Unique words after lemmatization: 6532

# %% [markdown]
# Prompts used (Taranjot) :-
# 1. How to tokenize text data ?
# 2. How can I perform lemmatization on the list of tokens?

# %% [markdown]
# Prompts used (Kabir) :-
# 1. How to count the number of unique words in a pandas ?
# 2. What is the use of explode in lemmatization?
