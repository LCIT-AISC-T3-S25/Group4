# %% [markdown]
# # AISC2009 - Natural Language Processing 01 (M07 Group 1)

# %% [markdown]
# SECTION B QUESTION 2

# %%
#Import required libraries
import pandas as pd
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Taranjot\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Taranjot\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Taranjot\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Load dataset
file_path = "D:\\Downloads\\Data.csv"  # Change the path based on your location
data = pd.read_csv(file_path)

# Clean the 'Data' column
def clean_data(column):
    column = column.str.lower()             # Convert to lowercase
    column = column.str.strip()             # Remove leading/trailing whitespace
    return column

data_cleaned = clean_data(data["Data"])

# %%
# Initialize the stemmer 
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
# Tokenization
tokens = data_cleaned.apply(word_tokenize)

# Perform stemming
tokens_stemmed = tokens.apply(lambda x: [stemmer.stem(word) for word in x])

# %%
# Count unique words before and after stemming
words_before_stemming = set(tokens.explode())
print("Unique words before stemming:", len(words_before_stemming))
# Out:
# Unique words before stemming: 8868

# %%
unique_words_after_stemming = set(tokens_stemmed.explode())
print("Unique words after stemming:", len(unique_words_after_stemming))
# Out:
# Unique words after stemming: 7560

# %% [markdown]
# Prompts used (Taranjot) :-
# 1. How to tokenize text data ?
# 2. How can I perform Stemming on the list of tokens?

# %% [markdown]
# Prompts used (Kabir) :-
# 1. How to count the number of unique words in a pandas ?
# 2. What is the use of explode in stemming?
