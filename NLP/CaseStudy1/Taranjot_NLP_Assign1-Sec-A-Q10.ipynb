# %% [markdown]
# # AISC2009 - Natural Language Processing 01 (M07 Group 1)

# %% [markdown]
# SECTION A QUESTION 10

# %%
#pip install nltk pandas

# %%
import pandas as pd
import re
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
# Download necessary NLTK data files
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Taranjot\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Taranjot\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Taranjot\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Loading the dataset
file_path = "D:\Downloads\Data.csv"  
data = pd.read_csv(file_path)

# %%
def clean_data(column):
    cleaned_column = column.str.lower()        # Convert to lowercase
    cleaned_column = cleaned_column.str.strip()  # Remove leading/trailing whitespace
    return cleaned_column

# Apply the cleaning function to the 'Data' column
data_cleaned = clean_data(data["Data"])

# %% [markdown]
# 10. What is the total number of URLs across all tweets?

# %%
url_pattern = r'https?://\S+|www\.\S+'
urls = data_cleaned.str.findall(url_pattern)
total_urls = urls.apply(len).sum()

# %%
print("Total URLs found:", total_urls)
# Out:
# Total URLs found: 4

# %% [markdown]
# Prompts used :-
# 1. How to clean text data by converting to lowercase and removing extra whitespace using pandas?
# 2. what is the regex used for url?
