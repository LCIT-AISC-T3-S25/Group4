# %%
import pandas as pd
import re
from google.colab import files

# Prompt user to upload a file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-daff5a10-6e52-4159-97cf-39970d2bbb5d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-daff5a10-6e52-4159-97cf-39970d2bbb5d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Assuming the uploaded file is a CSV and there's only one file uploaded
# Get the filename from the uploaded dictionary
filename = list(uploaded.keys())[0]

# Read the uploaded file into a pandas DataFrame
df = pd.read_csv(filename)

# Display the first few rows to understand the structure
print("Columns:", df.columns)
df.head()
# Out:
# Columns: Index(['Data'], dtype='object')
#                                                 Data
# 0  Watch or listen live weekdays at 8:30am MT at ...
# 1  Watch or listen live weekdays at 8:30am MT at ...
# 2               Chubby And Hot, Always Stir The Pot!
# 3               Chubby And Hot, Always Stir The Pot!
# 4  Journalist, publisher of Rebel News — telling ...

# %%
tweet_column = 'Data'

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from collections import Counter
import re

# Download required resources
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Function to clean and tokenize (before lemmatization)
def preprocess(text):
    text = str(text).lower()
    text = re.sub(r"http\S+|www\S+|@\w+|#\w+", "", text)  # Remove URLs, mentions, hashtags
    text = re.sub(r"[^a-z\s]", "", text)  # Remove punctuation and digits
    tokens = nltk.word_tokenize(text)
    tokens = [w for w in tokens if w not in stopwords.words('english') and len(w) > 2]
    return tokens

# Function to lemmatize a list of tokens
def lemmatize(tokens):
    return [lemmatizer.lemmatize(w) for w in tokens]

# Apply preprocessing and lemmatization
df['original_tokens'] = df[tweet_column].apply(preprocess)
df['lemmatized_tokens'] = df['original_tokens'].apply(lemmatize)

# Flatten all tokens
original_words = [word for tokens in df['original_tokens'] for word in tokens]
lemmatized_words = [word for tokens in df['lemmatized_tokens'] for word in tokens]

# Count unique words
unique_before = len(set(original_words))
unique_after = len(set(lemmatized_words))

# Print unique word counts
print(f"Unique words before lemmatization: {unique_before}")
print(f"🔸 Unique words after lemmatization: {unique_after}")

# Get word frequencies after lemmatization
word_freq = Counter(lemmatized_words)
top10 = word_freq.most_common(10)

# Print top 10 lemmatized words
print("\n🔹 Top 10 Words After Lemmatization:")
for word, count in top10:
    print(f"{word}: {count}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Unique words before lemmatization: 6808
# 🔸 Unique words after lemmatization: 6276
#
# 🔹 Top 10 Words After Lemmatization:
# alberta: 1030
# news: 593
# outdoor: 545
# canada: 543
# community: 543
# adventure: 514
# writer: 384
# park: 380
# love: 361
# follow: 361

# %%
# Download required resources
nltk.download('punkt')
nltk.download('stopwords')

# Initialize stemmer
stemmer = PorterStemmer()

# Function to clean and tokenize
def preprocess(text):
    text = str(text).lower()
    text = re.sub(r"http\S+|www\S+|@\w+|#\w+", "", text)  # Remove URLs, mentions, hashtags
    text = re.sub(r"[^a-z\s]", "", text)  # Remove punctuation and digits
    tokens = nltk.word_tokenize(text)
    tokens = [w for w in tokens if w not in stopwords.words('english') and len(w) > 2]
    return tokens

# Function to stem a list of tokens
def stem_tokens(tokens):
    return [stemmer.stem(w) for w in tokens]

# Apply to DataFrame
df['original_tokens'] = df[tweet_column].apply(preprocess)
df['stemmed_tokens'] = df['original_tokens'].apply(stem_tokens)

# Flatten token lists
original_words = [word for tokens in df['original_tokens'] for word in tokens]
stemmed_words = [word for tokens in df['stemmed_tokens'] for word in tokens]

# Unique word counts
unique_before = len(set(original_words))
unique_after = len(set(stemmed_words))

# Print comparison
print(f"Unique words before stemming: {unique_before}")
print(f"🔸 Unique words after stemming: {unique_after}")

# Top 10 most common stemmed words
word_freq = Counter(stemmed_words)
top10 = word_freq.most_common(10)

print("\n🔹 Top 10 Words After Stemming:")
for word, count in top10:
    print(f"{word}: {count}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Unique words before stemming: 6808
# 🔸 Unique words after stemming: 5515
#
# 🔹 Top 10 Words After Stemming:
# alberta: 1030
# outdoor: 686
# commun: 595
# news: 593
# canada: 543
# adventur: 528
# travel: 459
# follow: 446
# love: 410
# writer: 384
